# %% [markdown]
# ## Concatenación DataFrames
#
# ### 4. Union Prueba Saber 11 periodo 1 y periodo 2
#
# De acuerdo con la limpieza realizada para estas dos tablas y la información analizada, se realizará la union de los dos dataframes de las pruebas Saber 11 para un mejor análisis posterior.

# %% [markdown]
# #### Verificar tamaños de cada dataframe resultante

# %%
print("Data Frame Mintic: ", df_mintic_v2.shape)
print("Saber11 periodo 1: ", df_saber_1_v2.shape)
print("Saber11 periodo 2: ", df_saber_2_v2.shape)
# Out:
# Data Frame Mintic:  (429699, 11)
# Saber11 periodo 1:  (15435, 32)
# Saber11 periodo 2:  (504872, 32)

# %% [markdown]
# Se realiza la concatenación de los Data Frames Saber11 periodos 1 y 2 ya que cuentan con la misma información

# %%
df_saber_union = pd.concat( [df_saber_1_v2, df_saber_2_v2] )

# %% [markdown]
# Se comprueba los datos de inicio y final del data Frame resultante df_saber_union

# %%
df_saber_union.head(3)
# Out:
#                                      id ESTU_NACIONALIDAD ESTU_GENERO  \
# 0  00000000-0000-0000-B30A-5F2FE234EE93          COLOMBIA           F
# 1  00000000-0000-0000-F3E5-3E18272D8C28          COLOMBIA           F
# 2  00000000-0000-0000-2E67-572B8AFB010B          COLOMBIA           F
#
#   ESTU_FECHANACIMIENTO  ESTU_CONSECUTIVO ESTU_PAIS_RESIDE ESTU_DEPTO_RESIDE  \
# 0  1985-01-01T00:00:00  SB11202010045555         COLOMBIA             CESAR
# 1  1995-01-01T00:00:00  SB11202010045719         COLOMBIA            NARIÑO
# 2  1997-01-01T00:00:00  SB11202010070662         COLOMBIA             CAUCA
#
#   ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE ESTU_COD_RESIDE_MCPIO  ...  \
# 0                    20         SAN DIEGO                 20750  ...
# 1                    52           IPIALES                 52356  ...
# 2                    19            TOTORÓ                 19824  ...
#
#   PERCENTIL_C_NATURALES DESEMP_C_NATURALES PUNT_SOCIALES_CIUDADANAS  \
# ...

# %%
df_saber_union.tail(3)
# Out:
#                                           id ESTU_NACIONALIDAD ESTU_GENERO  \
# 504869  00000000-0000-0000-2F10-A90012384309          COLOMBIA           F
# 504870  00000000-0000-0000-03B3-B2EA58E0923E          COLOMBIA           M
# 504871  00000000-0000-0000-2054-CB6AE8FC9320          COLOMBIA           F
#
#        ESTU_FECHANACIMIENTO  ESTU_CONSECUTIVO ESTU_PAIS_RESIDE  \
# 504869  2005-01-14T00:00:00  SB11202040185843         COLOMBIA
# 504870  2002-06-14T00:00:00  SB11202040168607         COLOMBIA
# 504871  2002-02-20T00:00:00  SB11202040525571         COLOMBIA
#
#        ESTU_DEPTO_RESIDE ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  \
# 504869            BOGOTÁ                    11       BOGOTÁ D.C.
# 504870            BOGOTÁ                    11       BOGOTÁ D.C.
# 504871            BOGOTÁ                    11       BOGOTÁ D.C.
#
#        ESTU_COD_RESIDE_MCPIO  ... PERCENTIL_C_NATURALES DESEMP_C_NATURALES  \
# ...

# %% [markdown]
# #### Reindexación de Data Frame resultante
#
# Por conveniencia se dejará el índice como la cantidad de registros en el data frame resultante

# %%
df_saber_union_v1 = df_saber_union.reset_index(drop=True)
df_saber_union_v1
# Out:
#                                           id ESTU_NACIONALIDAD ESTU_GENERO  \
# 0       00000000-0000-0000-B30A-5F2FE234EE93          COLOMBIA           F
# 1       00000000-0000-0000-F3E5-3E18272D8C28          COLOMBIA           F
# 2       00000000-0000-0000-2E67-572B8AFB010B          COLOMBIA           F
# 3       00000000-0000-0000-114D-702F9FF236CA          COLOMBIA           F
# 4       00000000-0000-0000-46F2-F1A97370B387          COLOMBIA           F
# ...                                      ...               ...         ...
# 520302  00000000-0000-0000-C12C-959764F4F2FD          COLOMBIA           M
# 520303  00000000-0000-0000-CB12-D552B845A69E          COLOMBIA           M
# 520304  00000000-0000-0000-2F10-A90012384309          COLOMBIA           F
# 520305  00000000-0000-0000-03B3-B2EA58E0923E          COLOMBIA           M
# 520306  00000000-0000-0000-2054-CB6AE8FC9320          COLOMBIA           F
#
#        ESTU_FECHANACIMIENTO  ESTU_CONSECUTIVO ESTU_PAIS_RESIDE  \
# ...
